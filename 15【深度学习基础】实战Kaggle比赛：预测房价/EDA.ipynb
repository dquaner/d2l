# %% [markdown]
# # EDA House Prices

# %%
#!pip install seaborn

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# %matplotlib inline
from d2l import torch as d2l

# %% [markdown]
# ## load data

# %%
train_data = pd.read_csv('../data/KaggleHousePrices/kaggle_house_pred_train.csv')
test_data = pd.read_csv('../data/KaggleHousePrices/kaggle_house_pred_test.csv')

# %%
train_data.shape, test_data.shape
# Out:
# ((1460, 81), (1459, 80))

# %%
train_data.head(3)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
#
# [3 rows x 81 columns]

# %%
train_data = train_data.drop('Id', axis=1)
train_data.info()

# %% [raw]
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  3   LotFrontage    1201 non-null   float64  街道直线距离
#  6   Alley          91 non-null     object   胡同
#  25  MasVnrType     588 non-null    object   砖石类型
#  26  MasVnrArea     1452 non-null   float64  砖石贴面面积
#  30  BsmtQual       1423 non-null   object   地下室高度
#  31  BsmtCond       1423 non-null   object   地下室现状
#  32  BsmtExposure   1422 non-null   object   地下室墙壁
#  33  BsmtFinType1   1423 non-null   object   地下室完工面积质量
#  35  BsmtFinType2   1422 non-null   object   地下室完工面积质量2
#  42  Electrical     1459 non-null   object   电力系统
#  57  FireplaceQu    770 non-null    object   壁炉质量
#  58  GarageType     1379 non-null   object   车库位置
#  59  GarageYrBlt    1379 non-null   float64  车库建成年份
#  60  GarageFinish   1379 non-null   object   车库内部装修
#  63  GarageQual     1379 non-null   object   车库容量
#  64  GarageCond     1379 non-null   object   车库面积
#  72  PoolQC         7 non-null      object   游泳池质量
#  73  Fence          281 non-null    object   栅栏质量
#  74  MiscFeature    54 non-null     object   杂项

# %% [markdown]
# ## nan

# %%
na_cols = ['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
          'BsmtFinType1', 'BsmtFinType2', 'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
          'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature']
df_na = train_data[na_cols]
df_na
# Out:
#       LotFrontage Alley MasVnrType  MasVnrArea BsmtQual BsmtCond BsmtExposure  \
# 0            65.0   NaN    BrkFace       196.0       Gd       TA           No
# 1            80.0   NaN        NaN         0.0       Gd       TA           Gd
# 2            68.0   NaN    BrkFace       162.0       Gd       TA           Mn
# 3            60.0   NaN        NaN         0.0       TA       Gd           No
# 4            84.0   NaN    BrkFace       350.0       Gd       TA           Av
# ...           ...   ...        ...         ...      ...      ...          ...
# 1455         62.0   NaN        NaN         0.0       Gd       TA           No
# 1456         85.0   NaN      Stone       119.0       Gd       TA           No
# 1457         66.0   NaN        NaN         0.0       TA       Gd           No
# 1458         68.0   NaN        NaN         0.0       TA       TA           Mn
# 1459         75.0   NaN        NaN         0.0       TA       TA           No
#
# ...

# %%
df_na.hist()
# Out:
# array([[<Axes: title={'center': 'LotFrontage'}>,
#         <Axes: title={'center': 'MasVnrArea'}>],
#        [<Axes: title={'center': 'GarageYrBlt'}>, <Axes: >]], dtype=object)

# %%
df_num = train_data.select_dtypes(include=['float64', 'int64'])
df_num.hist(bins=50)
# Out:
# array([[<Axes: title={'center': 'MSSubClass'}>,
#         <Axes: title={'center': 'LotFrontage'}>,
#         <Axes: title={'center': 'LotArea'}>,
#         <Axes: title={'center': 'OverallQual'}>,
#         <Axes: title={'center': 'OverallCond'}>,
#         <Axes: title={'center': 'YearBuilt'}>],
#        [<Axes: title={'center': 'YearRemodAdd'}>,
#         <Axes: title={'center': 'MasVnrArea'}>,
#         <Axes: title={'center': 'BsmtFinSF1'}>,
#         <Axes: title={'center': 'BsmtFinSF2'}>,
#         <Axes: title={'center': 'BsmtUnfSF'}>,
#         <Axes: title={'center': 'TotalBsmtSF'}>],
#        [<Axes: title={'center': '1stFlrSF'}>,
#         <Axes: title={'center': '2ndFlrSF'}>,
#         <Axes: title={'center': 'LowQualFinSF'}>,
#         <Axes: title={'center': 'GrLivArea'}>,
#         <Axes: title={'center': 'BsmtFullBath'}>,
#         <Axes: title={'center': 'BsmtHalfBath'}>],
#        [<Axes: title={'center': 'FullBath'}>,
# ...
